# %% [markdown]
# <a href="https://colab.research.google.com/github/21500154/-SOLUTION-TO-A-SYSTEM-OF-LINEAR-EQUATIONS/blob/main/MLwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("train.csv")
from sklearn import linear_model
data.head()
data.tail()
data.isnull().sum()
#storing data to variable
X=data.LotArea
Y=data.SalePrice
print(X)
print(Y)
#defining variables
n=len(X)
m=0
c=0
L=0.01
loss=[]
for i in range(10000):
 ypred = m*X + c
 MSE = (1/n) * sum((ypred - Y)*2)
 dm = (2/n) * sum(X*(ypred-Y))
 dc = (2/n) * sum(ypred-Y)
 c = c-L*dc
 m = m-L*dm
 loss.append(MSE)
print("The Mean Square error",m,c)
#Plotting Linear Regression Graph
ypred=m*X+c
plt.scatter(X,Y,color="purple")
plt.plot(X,ypred,color="blue")
plt.xlabel("Study hours")
plt.ylabel("Scores")
plt.title("Study hours vs Scores")
#Graph between iteration Vs loss
plt.show()
# plt.title("study iteration vs loss)
plt.plot(loss)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.show()
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64
# The Mean Square error nan nan

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(data[['LotArea']],data.SalePrice)
plt.xlabel("Area")
plt.ylabel("SalePrice")
plt.scatter(data.LotArea,data.SalePrice,color="Red",marker="+")
plt.plot(data.LotArea,reg.predict(data[['LotArea']]),color='black')
for i in range(10000):
 loss.append(MSE)
print("Mean Squared Error= ",MSE)
reg.intercept_
# Out:
# Mean Squared Error=  nan
# 158836.1518968766
